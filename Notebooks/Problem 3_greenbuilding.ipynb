# %% [markdown]
# ### Problem Statement + Answers :

# %% [markdown]
# #### a.) Do you agree with the conclusions of her on-staff stats guru?
#
# Answer : I don't agree.

# %% [markdown]
# #### b.)If so, point to evidence supporting his case. If not, explain specifically where and why the analysis goes wrong, and how it can be improved.
#
# Answer :
# on-staff stats guru did two things :
#          i.removing very low occupancy rates data (good approach)
#          ii.used the median rent rather than the mean, because there were still some outliers in the data, and the median is a             lot more robust to outliers.(this went a little wrong)
#
# All of the estimates were correct except for the Minimum Occupancy Rate for the 8-Year Payback Period. It was approximately 96.15% rather than 90% as mentioned by stats guru.In addition, with a 70% occupancy rate, the investor would be able to profit after 11 years.(could be seen in graph in analysis below)
#
# Because the investor wishes to construct a 15-story building, the on-staff statistics guru made a mistake by using the median rent of all the  green and non-green buildings rather than the average rent of 15-storey green and non-green buildings.        In addition, as shown in the heatmap, storey and rent are positively correlated. With a minimum occupancy rate of 76.90%, the investor would begin earning money in the fourth year.And if she has 100% occupancy, she will start making profit within two years.

# %% [markdown]
# #### c.) Do you see the possibility of confounding variables for the relationship between rent and green status? If so, provide evidence for confounding, and see if you can also make a picture that visually shows how we might "adjust" for such a confounder. Tell your story in pictures, with appropriate introductory and supporting text.
#
# Answer:
# The significant correlation between rent and green status in the context of this analysis may indeed be affected by confounding variables. Confounding variables are additional variables that can affect both the independent variable (green status) and the dependent variable (rent), and if they are not properly taken into account, they may result to inaccurate findings.
# In the analysis, the rent difference between green and non-green buildings is compared.
# However, there might be other factors that are correlated with both green status and rent, which could confound the relationship.
#
# Some potential confounding variables in this case could include:
#
# 1.) Amenities: Buildings with amenities like gyms, dining options, or shopping areas may see higher rentals. As amenities are positively correlated with green ratings, the availability of these amenities may also be associated with status as environmentally friendly.
#
# 2.) Building Quality (Class A/B): Rent rates for various building classes may differ and may also be tied to the buildings' level of green certification. Higher-class structures might be more likely to be green-certified and to have higher rents. Green rating has a positive correlation with Class A and a negative correlation with Class B.
#
# 3.) Building Size: Due to the more space, larger buildings may have higher rates. The decision to go green may also be influenced by the building's size as size and green rating are positively correlated.
#
# 4.) Building Age and Renovation: Older buildings might be less likely to be green-certified and could have different rent dynamics.Age has negative correlation with green rating.
#
# 5.) Market Trends: Market trends and economic conditions can impact both rent levels and the decision to adopt green practices.
# Gas costs is negatively correlated  with green ratings and electricity costs is positively correlated with green ratings.
#
# 6.) Location: The geographic location of a building can influence rent. Certain areas might have a higher demand for green buildings, impacting both green certification and rent. Precipitation is negatively correlated with green ratings.
#
# Note : Pictures are in analysis below.

# %% [markdown]
# ### Goal : Clearly explain the financial feasibility of creating a green building and how various elements, such as occupancy rates and green status, can influence the payback period.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data = pd.read_csv('greenbuildings.csv')
data[0:4]
# Out:
#    CS_PropertyID  cluster    size  empl_gr   Rent  leasing_rate  stories  age  \
# 0         379105        1  260300     2.22  38.56         91.39       14   16
# 1         122151        1   67861     2.22  28.57         87.14        5   27
# 2         379839        1  164848     2.22  33.31         88.94       13   36
# 3          94614        1   93372     2.22  35.00         97.04       13   46
#
#    renovated  class_a  ...  green_rating  net  amenities  cd_total_07  \
# 0          0        1  ...             1    0          1         4988
# 1          0        0  ...             0    0          1         4988
# 2          1        0  ...             0    0          1         4988
# 3          1        0  ...             0    0          0         4988
#
#    hd_total07  total_dd_07  Precipitation  Gas_Costs  Electricity_Costs  \
# 0          58         5046          42.57   0.013700           0.029000
# 1          58         5046          42.57   0.013731           0.029045
# ...

# %%
data.describe()
# Out:
#        CS_PropertyID      cluster          size      empl_gr         Rent  \
# count   7.894000e+03  7894.000000  7.894000e+03  7820.000000  7894.000000
# mean    4.530025e+05   588.615024  2.346377e+05     3.206720    28.418569
# std     7.434053e+05   399.907509  2.975334e+05     8.162989    15.075483
# min     1.000000e+00     1.000000  1.624000e+03   -24.950000     2.980000
# 25%     1.574520e+05   272.000000  5.089125e+04     1.740000    19.500000
# 50%     3.132530e+05   476.000000  1.288380e+05     1.970000    25.160000
# 75%     4.411885e+05  1044.000000  2.942120e+05     2.380000    34.180000
# max     6.208103e+06  1230.000000  3.781045e+06    67.780000   250.000000
#
#        leasing_rate      stories          age    renovated      class_a  ...  \
# count   7894.000000  7894.000000  7894.000000  7894.000000  7894.000000  ...
# mean      82.606371    13.584495    47.243983     0.379529     0.399924  ...
# ...

# %%
# Data Cleaning
data_cleaned = data[data['leasing_rate'] >= 0.1]

# %%
data_cleaned.describe()
# Out:
#        CS_PropertyID      cluster          size      empl_gr         Rent  \
# count   7.734000e+03  7734.000000  7.734000e+03  7661.000000  7734.000000
# mean    4.356042e+05   589.410396  2.384258e+05     3.184759    28.556928
# std     6.869587e+05   400.216773  2.992360e+05     8.136265    15.107641
# min     1.000000e+00     1.000000  2.378000e+03   -24.950000     2.980000
# 25%     1.574512e+05   272.000000  5.162975e+04     1.740000    19.500000
# 50%     3.132410e+05   477.000000  1.308110e+05     1.970000    25.200000
# 75%     4.408640e+05  1044.000000  3.000000e+05     2.380000    34.200000
# max     6.208103e+06  1230.000000  3.781045e+06    67.780000   250.000000
#
#        leasing_rate      stories          age    renovated      class_a  ...  \
# count   7734.000000  7734.000000  7734.000000  7734.000000  7734.000000  ...
# mean      84.315310    13.778381    47.100078     0.381821     0.406905  ...
# ...

# %% [markdown]
# #### There are 160 buildings(2% of total data) in the data set had very low occupancy rates (less than 10% of available space occupied).This is very low number so, won't affect analysis. Dropping this is a great idea!

# %%
data_cleaned.columns.values
# Out:
# array(['CS_PropertyID', 'cluster', 'size', 'empl_gr', 'Rent',
#        'leasing_rate', 'stories', 'age', 'renovated', 'class_a',
#        'class_b', 'LEED', 'Energystar', 'green_rating', 'net',
#        'amenities', 'cd_total_07', 'hd_total07', 'total_dd_07',
#        'Precipitation', 'Gas_Costs', 'Electricity_Costs', 'cluster_rent'],
#       dtype=object)

# %%
# Create a line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='stories', y='Rent', data=data_cleaned)
plt.title('Rent Trends vs. Number of Stories')
plt.xlabel('Number of Stories')
plt.ylabel('Rent ($ per sqft per year)')
plt.grid()
plt.show()

# %%
# Rent Comparison
plt.figure(figsize=(8, 6))
sns.boxplot(x='green_rating', y='Rent', data=data_cleaned)
plt.title('Rent Distribution by Green Rating')
plt.xlabel('Green Rating')
plt.ylabel('Rent ($ per sqft per year)')
plt.show()

# %%
# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='green_rating', y='s', data=data_cleaned)
plt.title('Building Size vs. Green Rating')
plt.xlabel('Green Rating')
plt.ylabel('Building Size (sqft)')
plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = data_cleaned.corr()

# %%
# Create a heatmap
plt.figure(figsize=(16, 18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Select relevant columns
selected_columns = ['Rent', 'size', 'stories', 'green_rating']
data_selected = data_cleaned[selected_columns]

# Create a scatter plot matrix
sns.pairplot(data_selected, hue='green_rating', diag_kind='kde', markers=["o", "s"])
plt.suptitle('Scatter Plot Matrix: Rent, Building Size, Stories, and Green Rating', y=1.02)
plt.show()
# Out:
# C:\Users\Deepti\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Deepti\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ### Analysis by taking average rent of 15 storey buildings

# %%
# Filter data for buildings with 15 stories
data_15_stories = data_cleaned[data_cleaned['stories'] == 15]

# Calculate rent for green and non-green buildings
rent_green = data_15_stories[data_15_stories['green_rating'] == 1]['Rent'].mean()
rent_non_green = data_15_stories[data_15_stories['green_rating'] == 0]['Rent'].mean()

print(f"Average Rent for Green Buildings with 15 Stories: ${rent_green:.2f}")
print(f"Average Rent for Non-Green Buildings with 15 Stories: ${rent_non_green:.2f}")
# Out:
# Average Rent for Green Buildings with 15 Stories: $34.95
# Average Rent for Non-Green Buildings with 15 Stories: $26.29

# %%
extra_rent_persqft = rent_green - rent_non_green
print('Extra rent per sqft for green building : $',extra_rent_persqft)
# Out:
# Extra rent per sqft for green building : $ 8.66880769230768

# %%
building_size = 250000  # sqft
extra_revenue_annual1 = extra_rent_persqft * building_size
print('Extra annual revenue for building size of 250000 sqft : $',extra_revenue_annual1)
# Out:
# Extra annual revenue for building size of 250000 sqft : $ 2167201.92307692

# %%
green_certification_premium = 0.05  # 5%
extra_cost1 = green_certification_premium * 100000000  # $100 million
print('Extra cost to be incurred by investor for green building certification : $',extra_cost1)
# Out:
# Extra cost to be incurred by investor for green building certification : $ 5000000.0

# %%
payback_period_years1 = extra_cost1 / extra_revenue_annual1
payback_period_years1
# Out:
# 2.307122352909861

# %%
# Visualize Revenue and Costs
plt.figure(figsize=(8, 6))
plt.bar(['Extra Revenue', 'Extra Cost'], [extra_revenue_annual1, extra_cost1], color=['green', 'red'])
plt.title('Extra Revenue vs. Extra Cost')
plt.ylabel('Amount ($)')
plt.show()

# %%
# Sensitivity Analysis
occupancy_rates1 = range(70, 101, 5)
payback_periods1 = [extra_cost1 / (extra_revenue_annual1 * rate / 100) for rate in occupancy_rates1]

plt.figure(figsize=(8, 6))
plt.plot(occupancy_rates1, payback_periods1, marker='o')
plt.title('Sensitivity Analysis: Payback Period vs. Occupancy Rate')
plt.xlabel('Occupancy Rate (%)')
plt.ylabel('Payback Period (Years)')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate minimum occupancy rate for a given payback period
def calculate_min_occupancy(extra_cost1, extra_revenue_annual1, target_payback_period1):
    return extra_cost1 / (extra_revenue_annual1 * target_payback_period1)

# Given payback period (years)
target_payback_period1 = 3  # Example: 8 years

# Calculate minimum occupancy rate
min_occupancy_rate1 = calculate_min_occupancy(extra_cost1, extra_revenue_annual1, target_payback_period1)

# Visualize the minimum occupancy rate
plt.figure(figsize=(6, 4))
plt.plot([min_occupancy_rate1 * 100], [target_payback_period1], marker='o', color='r', label='Minimum Occupancy Rate')
plt.xlabel('Occupancy Rate (%)')
plt.ylabel('Payback Period (Years)')
plt.title('Minimum Occupancy Rate for Target Payback Period')
plt.legend()
plt.grid()
plt.show()

print(f"Minimum Occupancy Rate for {target_payback_period1} Years Payback Period: {min_occupancy_rate1:.2%}")
# Out:
# Minimum Occupancy Rate for 3 Years Payback Period: 76.90%

# %% [markdown]
# ### Analysis as suggested by stats guru

# %%
# Revenue and Cost Calculation
median_rent_non_green = data_cleaned[data_cleaned['green_rating'] == 0]['Rent'].median()
print('Median Rent for non-green building : ',median_rent_non_green)
# Out:
# Median Rent for non-green building :  25.0

# %%
median_rent_green = data_cleaned[data_cleaned['green_rating'] == 1]['Rent'].median()
print('Median Rent for green building : ',median_rent_green)
# Out:
# Median Rent for green building :  27.6

# %%
extra_rent_per_sqft = median_rent_green - median_rent_non_green
print('Extra rent per sqft for green building : ',extra_rent_per_sqft)
# Out:
# Extra rent per sqft for green building :  2.6000000000000014

# %%
building_size = 250000  # sqft
extra_revenue_annual = extra_rent_per_sqft * building_size
print('Extra annual revenue for building size of 250000 sqft : ',extra_revenue_annual)
# Out:
# Extra annual revenue for building size of 250000 sqft :  650000.0000000003

# %%
green_certification_premium = 0.05  # 5%
extra_cost = green_certification_premium * 100000000  # $100 million
print('Extra cost to be incurred by investor for green building certification : ',extra_cost)
# Out:
# Extra cost to be incurred by investor for green building certification :  5000000.0

# %%
payback_period_years = extra_cost / extra_revenue_annual
payback_period_years
# Out:
# 7.692307692307688

# %%
# Visualize Revenue and Costs
plt.figure(figsize=(8, 6))
plt.bar(['Extra Revenue', 'Extra Cost'], [extra_revenue_annual, extra_cost], color=['green', 'red'])
plt.title('Extra Revenue vs. Extra Cost')
plt.ylabel('Amount ($)')
plt.show()

# %%
# Sensitivity Analysis
occupancy_rates = range(70, 101, 5)
payback_periods = [extra_cost / (extra_revenue_annual * rate / 100) for rate in occupancy_rates]

plt.figure(figsize=(8, 6))
plt.plot(occupancy_rates, payback_periods, marker='o')
plt.title('Sensitivity Analysis: Payback Period vs. Occupancy Rate')
plt.xlabel('Occupancy Rate (%)')
plt.ylabel('Payback Period (Years)')
plt.grid()
plt.show()

# %% [markdown]
# #### Payback period would increase if occupancy rate will decrease.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate minimum occupancy rate for a given payback period
def calculate_min_occupancy(extra_cost, extra_revenue_annual, target_payback_period):
    return extra_cost / (extra_revenue_annual * target_payback_period)

# Given payback period (years)
target_payback_period = 8  # Example: 8 years

# Calculate minimum occupancy rate
min_occupancy_rate = calculate_min_occupancy(extra_cost, extra_revenue_annual, target_payback_period)

# Visualize the minimum occupancy rate
plt.figure(figsize=(6, 4))
plt.plot([min_occupancy_rate * 100], [target_payback_period], marker='o', color='r', label='Minimum Occupancy Rate')
plt.xlabel('Occupancy Rate (%)')
plt.ylabel('Payback Period (Years)')
plt.title('Minimum Occupancy Rate for Target Payback Period')
plt.legend()
plt.grid()
plt.show()

print(f"Minimum Occupancy Rate for {target_payback_period} Years Payback Period: {min_occupancy_rate:.2%}")
# Out:
# Minimum Occupancy Rate for 8 Years Payback Period: 96.15%
